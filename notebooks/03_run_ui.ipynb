# %% [markdown]
# # PowerTrust — Malaysia Solar Intelligence UI
# Run each cell in order.

# %%
# Step 1: Mount Google Drive
from google.colab import drive
drive.mount('/content/drive')
print('Google Drive mounted')
# Out:
# Mounted at /content/drive
# Google Drive mounted

# %%
# Step 2: Install packages
# !pip install streamlit langchain langchain-community langchain-core -q
# !pip install langchain-huggingface langchain-text-splitters -q
# !pip install chromadb sentence-transformers -q
# !pip install groq ddgs python-dotenv -q
# !pip install pyngrok -q
print('Packages installed')
# Out:
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 9.1/9.1 MB 95.1 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.5/2.5 MB 5.2 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.0/1.0 MB 39.3 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 6.9/6.9 MB 87.5 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 64.9/64.9 kB 3.1 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 51.0/51.0 kB 2.2 MB/s eta 0:00:00
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# google-colab 1.0.0 requires requests==2.32.4, but you have requests 2.33.1 which is incompatible.
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 52.0/52.0 kB 1.4 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 23.0/23.0 MB 71.7 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 278.2/278.2 kB 15.0 MB/s eta 0:00:00
# ...

# %%
# Step 3: Set Groq API Key
from google.colab import userdata

api_key = userdata.get('GROQ_API_KEY4')

if api_key:
    print("✅ API key loaded")
else:
    print("❌ API key not found")
# Out:
# ✅ API key loaded

# %%
# Out:
# True

# %%
# Step: Set ngrok Authtoken (from Colab secrets)

from google.colab import userdata
import os
import subprocess

# 1.  token bring from Colab secrets
ngrok_token = userdata.get('ngrok_key')


if ngrok_token:
    print("✅ ngrok token loaded")

    # 2. ngrok config  authtoken setting
    subprocess.run(
        ["ngrok", "config", "add-authtoken", ngrok_token],
        check=True
    )

    print("✅ ngrok authtoken configured")
else:
    print("❌ ngrok token not found")
# Out:
# ✅ ngrok token loaded
# ✅ ngrok authtoken configured

# %%
# Step 4
# !cp '/content/drive/.shortcut-targets-by-id/1MdK2VZM_imqTJTfopqamlRJvID4o3GVG/Hackathon/RAG/app.py' /content/app.py
print(os.path.exists('/content/app.py'))
# Out:
# cp: cannot stat '/content/drive/.shortcut-targets-by-id/1MdK2VZM_imqTJTfopqamlRJvID4o3GVG/Hackathon/RAG/app.py': No such file or directory
# True

# %%
from pyngrok import ngrok
import subprocess
import time
import os
from dotenv import load_dotenv

# .env load
ENV_PATH = "/content/drive/.shortcut-targets-by-id/1MdK2VZM_imqTJTfopqamlRJvID4o3GVG/Hackathon/RAG/.env"
load_dotenv(ENV_PATH)

ngrok.kill()


env = os.environ.copy()

proc = subprocess.Popen(
    ['streamlit', 'run', '/content/app.py',
     '--server.port', '8501',
     '--server.headless', 'true',
     '--server.enableCORS', 'false'],
    stdout=subprocess.PIPE,
    stderr=subprocess.PIPE,
    env=env  # ← Passing environment variables
)

time.sleep(5)

public_url = ngrok.connect(8501)
print('PowerTrust UI is live!')
print(f'Open this URL: {public_url}')
# Out:
# PowerTrust UI is live!
# Open this URL: NgrokTunnel: "https://grumbly-unworldly-thirsty.ngrok-free.dev" -> "http://localhost:8501"

# %%
# Optional: Stop the app
# ngrok.kill()
# proc.terminate()
# print('Stopped')

# %%
# 1. force quit
import subprocess
subprocess.run(['fuser', '-k', '8501/tcp'], capture_output=True)
subprocess.run(['pkill', '-9', '-f', 'streamlit'], capture_output=True)

import time
time.sleep(3)

# 2. check the port
result = subprocess.run(['fuser', '8501/tcp'], capture_output=True, text=True)
print("Port 8501 used by:", result.stdout)
print("Should be empty ↑")
# Out:
# Port 8501 used by:
# Should be empty ↑
